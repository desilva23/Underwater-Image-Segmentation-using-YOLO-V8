# %%
# !pip install ultralytics
# Out:
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\numpy-1.20.3.dist-info\\direct_url.json'
# Consider using the `--user` option or check the permissions.

# %%
import requests

# %%
import zipfile
import os
import glob

import matplotlib.pyplot as plt
import random
import numpy as np

# %%
 pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)

# %%
# !pip install opencv-python
# Out:
# ...
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.5.3

# %%
def download_file(url, save_name):
    url = url
    if not os.path.exists(save_name):
        file = requests.get(url)
        open(save_name, 'wb').write(file.content)

# %%
def unzip(zip_file):
    try:
        with zipfile.ZipFile(zip_file) as z:
            z.extractall("./")
            print("Extracted all")
    except:
        print("Invalid file")

# %%
download_file(
    'https://www.dropbox.com/scl/fi/lt7gu0p0itsi0wmy224vi/trash_inst_material.zip?rlkey=qvvly8z0egxdok5va27q2qn1t&dl=0',
    'trash_inst_material.zip'
)

unzip(zip_file='trash_inst_material.zip')
# Out:
# Invalid file

# %%
# !pip install requests
# Out:
# ...
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import os
import requests

def download_file(url, save_name):
    if not os.path.exists(save_name):
        file = requests.get(url)
        open(save_name, 'wb').write(file.content)

# Call the function with your desired URL and save name
download_file('https://www.dropbox.com/scl/fi/lt7gu0p0itsi0wmy224vi/trash_inst_material.zip?rlkey=qvvly8z0egxdok5va27q2qn1t&dl=0'
, 'trash_inst_material.zip')

# %%
cd C:\Users\student.MCC\Desktop\UNDER WATER TRASH DETECTION\
# Out:
# C:\Users\student.MCC\Desktop\UNDER WATER TRASH DETECTION

# %%
# !unzip "trash_inst_material.zip"
# Out:
# Archive:  trash_inst_material.zip
#    creating: trash_inst_material/
#    creating: trash_inst_material/train/
#    creating: trash_inst_material/train/labels/
#   inflating: trash_inst_material/train/labels/vid_000437_frame0000015.txt
#   inflating: trash_inst_material/train/labels/vid_000346_frame0000020.txt
#   inflating: trash_inst_material/train/labels/vid_000331_frame0000158.txt
#   inflating: trash_inst_material/train/labels/vid_000332_frame0000054.txt
#   inflating: trash_inst_material/train/labels/vid_000270_frame0000026.txt
#   inflating: trash_inst_material/train/labels/vid_000236_frame0000060.txt
#   inflating: trash_inst_material/train/labels/vid_000159_frame0000002.txt
#   inflating: trash_inst_material/train/labels/vid_000264_frame0000073.txt
#   inflating: trash_inst_material/train/labels/vid_000440_frame0000122.txt
#   inflating: trash_inst_material/train/labels/vid_000155_frame0000052.txt
#   inflating: trash_inst_material/train/labels/vid_000287_frame0000007.txt
# ...

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\student.MCC\Desktop\UNDER WATER TRASH DETECTION

# %%
import yaml

attr = {
    'path': cwd+'/trash_inst_material',
    'train': 'train/images',
    'val': 'val/images',

    'names': {
        0: 'rov',
        1: 'plant',
        2: 'animal_fish',
        3: 'animal_starfish',
        4: 'animal_shells',
        5: 'animal_crab',
        6: 'animal_eel',
        7: 'animal_etc',
        8: 'trash_etc',
        9: 'trash_fabric',
        10: 'trash_fishing_gear',
        11: 'trash_metal',
        12: 'trash_paper',
        13: 'trash_plastic',
        14: 'trash_rubber',
        15: 'trash_wood',
    }
}

# %%
with open('trashcan_inst_material.yaml', 'w') as f:
    yaml.dump(attr, f)

# %%
EPOCHS = 5
# !yolo \
task=segment \
mode=train \
model=yolov8n-seg.pt \
imgsz=640 \
data=trashcan_inst_material.yaml \
epochs={EPOCHS} \
batch=8 \
name=yolov8m-seg \
exist_ok=True \
amp=False
# Out:
# 'yolo' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip uninstall ultralytics
# Out:
# WARNING: Skipping ultralytics as it is not installed.

# %%
# !pip install ultralytics

# %%
EPOCHS = 5
# !yolo \
task=segment \
mode=train \
model=yolov8n-seg.pt \
imgsz=640 \
data=trashcan_inst_material.yaml \
epochs={EPOCHS} \
batch=8 \
name=yolov8m-seg \
exist_ok=True \
amp=False
